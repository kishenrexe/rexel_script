# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_excel('EC011141.xlsx')

data1
# Out:
#     Unnamed: 0        code etim class  \
# 0            0  2850326178   EC011141
# 1            1  2850326178   EC011141
# 2            2  2850326178   EC011141
# 3            3  2850326178   EC011141
# 4            4  2850326178   EC011141
# ..         ...         ...        ...
# 65          65  2850512172   EC011141
# 66          66  2850512172   EC011141
# 67          67  2850512172   EC011141
# 68          68  2850512172   EC011141
# 69          69  2850512172   EC011141
#
#                           orginele webtitel etim value class  \
# 0   Polyester touw 8 mm 120 mtr incl Haspel   EV000206  Touw
# 1   Polyester touw 8 mm 120 mtr incl Haspel        NaN  Touw
# 2   Polyester touw 8 mm 120 mtr incl Haspel   EV000819  Touw
# 3   Polyester touw 8 mm 120 mtr incl Haspel   EV000233  Touw
# 4   Polyester touw 8 mm 120 mtr incl Haspel        NaN  Touw
# ..                                      ...        ...   ...
# 65    Polyester Touw Ø10mm 200m incl.Haspel   EV000233  Touw
# ...

# %%
test = data1.pivot(index='code', columns='waarde', values='kenmerkwaarde')

test
# Out:
# waarde     Breukbelasting Dikte Elastisch  Kleur Kleur op band/streep Lengte  \
# code
# 2850326178         21.379     8       NaN  Zwart                 Rood    120
# 2850447631            NaN     3       Nee    Wit                 Geen    750
# 2850447632            NaN     3       Nee  Zwart                 Geen    750
# 2850512167         21.379    12       NaN  Zwart                 Rood    150
# 2850512168         21.379    12       NaN  Zwart                 Rood    200
# 2850512169         21.379    12       NaN  Zwart                 Rood    300
# 2850512170         21.379    12       NaN  Zwart                 Rood    350
# 2850512171         21.379    10       NaN  Zwart                 Rood    120
# 2850512172         21.379    10       NaN  Zwart                 Rood    200
#
# waarde               Materiaal  Uitvoering
# code
# 2850326178           Polyester  Gevlochten
# 2850447631  Polypropyleen (PP)    Gedraaid
# 2850447632  Polypropyleen (PP)    Gedraaid
# ...

# %%
data1.pivot_table(index='code', columns =['waarde',])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data1.unstack('waarde')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\frame.py:9112, in DataFrame.unstack(self, level, fill_value)
#    9050 """
#    9051 Pivot a level of the (necessarily hierarchical) index labels.
#    9052
#    (...)
#    9108 dtype: float64
#    9109 """
#    9110 from pandas.core.reshape.reshape import unstack
# -> 9112 result = unstack(self, level, fill_value)
#    9114 return result.__finalize__(self, method="unstack")
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py:472, in unstack(obj, level, fill_value)
#     470 # Prioritize integer interpretation (GH #21677):
#     471 if not is_integer(level) and not level == "__placeholder__":
# --> 472     level = obj.index._get_level_number(level)
# ...

# %%
d1 = {'col1': [1,2], 'col2':[3,4]}

# %%
df = pd.DataFrame({'A': {0:'a',1:'b',2: 'c'},'B': {0:1,1:3,2:5},'C':{0:2,1:4,2:6}})

df

# %%
df = pd.DataFrame({'date': {0: '5/1/2017',1: '5/2/2017',2: '5/3/2017',3: '5/1/2017',4: '5/2/2017',5: '5/3/2017',6: '5/1/2017',7: '5/2/2017',8: '5/3/2017'},'city': {0: 'new york', 1: 'new york', 2: 'new york', 3: 'mumbai', 4: 'mumbai', 5: 'mumbai', 6: 'beijing', 7: 'beijing', 8:'beijing'},'temperature': {0: 65, 1: 66, 2: 68, 3: 75, 4: 78, 5: 82, 6: 80, 7: 77, 8: 79 }, 'humidity': {0: 56, 1: 58, 2: 60, 3: 80, 4: 83, 5: 85, 6: 26, 7: 30, 8: 35}})

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index= "date", columns="city")
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
tester = data.pivot(index="code", columns ="waarde", values = "kenmerkwaarde")

# %%
data.dropna(how='any')
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, code, etim class, orginele webtitel, etim value, class, waarde, kenmerkwaarde, kenmerkwaarde max, eenheid, merk, type, serie, artikelnummer fabrikant, technische omschrijving]
# Index: []

# %%
data
# Out:
#     Unnamed: 0        code etim class  \
# 0            0  2850326178   EC011141
# 1            1  2850326178   EC011141
# 2            2  2850326178   EC011141
# 3            3  2850326178   EC011141
# 4            4  2850326178   EC011141
# ..         ...         ...        ...
# 65          65  2850512172   EC011141
# 66          66  2850512172   EC011141
# 67          67  2850512172   EC011141
# 68          68  2850512172   EC011141
# 69          69  2850512172   EC011141
#
#                           orginele webtitel etim value class  \
# 0   Polyester touw 8 mm 120 mtr incl Haspel   EV000206  Touw
# 1   Polyester touw 8 mm 120 mtr incl Haspel        NaN  Touw
# 2   Polyester touw 8 mm 120 mtr incl Haspel   EV000819  Touw
# 3   Polyester touw 8 mm 120 mtr incl Haspel   EV000233  Touw
# 4   Polyester touw 8 mm 120 mtr incl Haspel        NaN  Touw
# ..                                      ...        ...   ...
# 65    Polyester Touw Ø10mm 200m incl.Haspel   EV000233  Touw
# ...

# %%
data = pd.DataFrame(np.arange(6).reshape((2, 3)),
....: index=pd.Index(['Ohio', 'Colorado'], name='state'),
....: columns=pd.Index(['one', 'two', 'three'], name='number'))

# %%
data
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %%
result = data.stack()

result
# Out:
# state     number
# Ohio      one       0
#           two       1
#           three     2
# Colorado  one       3
#           two       4
#           three     5
# dtype: int32

# %%
data.isnull(Nan))

# %%
df = pd.read_csv('WordsByCharacter.csv')

df
# Out:
#                            Film                 Chapter  Character    Race  \
# 0    The Fellowship Of The Ring            01: Prologue      Bilbo  Hobbit
# 1    The Fellowship Of The Ring            01: Prologue     Elrond     Elf
# 2    The Fellowship Of The Ring            01: Prologue  Galadriel     Elf
# 3    The Fellowship Of The Ring            01: Prologue     Gollum  Gollum
# 4    The Fellowship Of The Ring  02: Concerning Hobbits      Bilbo  Hobbit
# ..                          ...                     ...        ...     ...
# 726      The Return Of The King     76: The Grey Havens     Elrond     Elf
# 727      The Return Of The King     76: The Grey Havens      Frodo  Hobbit
# 728      The Return Of The King     76: The Grey Havens  Galadriel     Elf
# 729      The Return Of The King     76: The Grey Havens    Gandalf   Ainur
# 730      The Return Of The King     76: The Grey Havens        Sam  Hobbit
#
#      Words
# 0        4
# 1        5
# 2      460
# 3       20
# ...

# %%
df.index.names
# Out:
# FrozenList([None])

# %%
multi = df.set_index(['Film','Chapter', 'Race','Character' ])

multi
# Out:
#                                                                     Words
# Film                       Chapter                Race   Character
# The Fellowship Of The Ring 01: Prologue           Hobbit Bilbo          4
#                                                   Elf    Elrond         5
#                                                          Galadriel    460
#                                                   Gollum Gollum        20
#                            02: Concerning Hobbits Hobbit Bilbo        214
# ...                                                                   ...
# The Return Of The King     76: The Grey Havens    Elf    Elrond         6
#                                                   Hobbit Frodo        132
#                                                   Elf    Galadriel     17
#                                                   Ainur  Gandalf       42
#                                                   Hobbit Sam           14
#
# ...

# %%
multi.index.values
# Out:
# array([('The Fellowship Of The Ring', '01: Prologue', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '01: Prologue', 'Elf', 'Elrond'),
#        ('The Fellowship Of The Ring', '01: Prologue', 'Elf', 'Galadriel'),
#        ('The Fellowship Of The Ring', '01: Prologue', 'Gollum', 'Gollum'),
#        ('The Fellowship Of The Ring', '02: Concerning Hobbits', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Frodo'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Ainur', 'Gandalf'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Hobbit Kids'),
#        ('The Fellowship Of The Ring', '03: The Shire', 'Hobbit', 'Hobbits'),
#        ('The Fellowship Of The Ring', '04: Very Old Friends', 'Hobbit', 'Bilbo'),
#        ('The Fellowship Of The Ring', '04: Very Old Friends', 'Ainur', 'Gandalf'),
# ...
